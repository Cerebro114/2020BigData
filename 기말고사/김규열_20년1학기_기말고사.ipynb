# %% [markdown]
# # 2020년 1학기 기말시험

# %% [markdown]
# # 이름 : 김규열

# %% [markdown]
# https://colab.research.google.com/에 import하여 셀에 답을 적고 RUN하십시오. 출력한 결과에 따라 스코어링됩니다.

# %% [markdown]
# Q1. CNN 신경망에서 2D 컨볼루션 레이어를 거친 행렬의 값을 파이썬 array형태로 적으시오. 계산을 위해 계산기앱 또는 액셀을 사용해도 좋습니다.

# %%
""" 문제
x = [[1,2,3],
     [4,5,6],
     [7,8,9]]
     
kernel W =[[0,1],
          [1,0]]

Padding = VALID

convolution을 한 결과를 행렬 y로 하여 print(y)로 출력하시오.
"""
y=   # 여러분의 answer를 파이썬 어레이로 적고 Run하시오.
print(y)

# %% [markdown]
# Q2, 아래의 Confusion Matrix를 보고 질문에 답하시오

# %%
# 문제 : 아래의 혼동행렬을 보고 TPR과 FNR을 계산하시오. 단 계산하는 공식을 파이썬으로 코딩하여 값을 구하시오.
# 혼동행렬의 row는 실제값, column은 예측값, (1,1)이 True & Positive
# 정의 : TPR = True Postive rate, FNR = False Negative rate
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

array = np.array([[850,6],
                  [50,94]])         

sn.set(font_scale=2.0) # for label size
sn.heatmap(array, annot=True, annot_kws={"size": 18}, fmt='d') # font size

plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
# Q2.1 TPR=?  아래에 계산식을 쓰고 Run 시키시오
# 여러분의 코드 
array = np.array(array)
tpr=array[1,1]/(array[0,1]+array[1,1])
print('TPR값은 ', tpr)
# Out:
# TPR값은  0.94

# %%
# Q2.2 FNR 계산을 위한 코드를 쓰고  Run하시오
# 여러분의 코드 
array = np.array(array)
fnr=array[1,0]/(array[1,0]+array[0,0])
print('FNR값은 ', fnr)
# Out:
# FNR값은  0.05555555555555555

# %%
#  Q2.3 accurary 계산을 위한 코드를 쓰고  Run하시오
# 여러분의 코드
array = np.array(array)
acc = (array[1,1] + array[0,0]) / (array[1,0]+array[0,0]+array[0,1]+array[1,1])
print('Accuracy 값은 ', acc)
# Out:
# Accuracy 값은  0.944

# %% [markdown]
# Q3. 다음 신경망 다이어그램을 보고 이를 구현하기 위한 파이썬 코드를 완성하시오

# %%
! wget --no-check-certificate 'https://docs.google.com/uc?export=download&id=1jGQthuWngRlgUq7masWosTq1LyzwUAS7' -O 퍼셉트론.png
from IPython.display import Image
Image("퍼셉트론.png", width=500)
# Out:
# --2020-06-10 05:04:01--  https://docs.google.com/uc?export=download&id=1jGQthuWngRlgUq7masWosTq1LyzwUAS7
# Resolving docs.google.com (docs.google.com)... 172.217.203.113, 172.217.203.100, 172.217.203.102, ...
# Connecting to docs.google.com (docs.google.com)|172.217.203.113|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-0s-1s-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/4hmo83b1gckhv6e5631nitkm1f1l3hcd/1591765425000/04591858293269658552/*/1jGQthuWngRlgUq7masWosTq1LyzwUAS7?e=download [following]
# Warning: wildcards not supported in HTTP.
# --2020-06-10 05:04:01--  https://doc-0s-1s-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/4hmo83b1gckhv6e5631nitkm1f1l3hcd/1591765425000/04591858293269658552/*/1jGQthuWngRlgUq7masWosTq1LyzwUAS7?e=download
# Resolving doc-0s-1s-docs.googleusercontent.com (doc-0s-1s-docs.googleusercontent.com)... 172.217.204.132, 2607:f8b0:400c:c15::84
# Connecting to doc-0s-1s-docs.googleusercontent.com (doc-0s-1s-docs.googleusercontent.com)|172.217.204.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 18076 (18K) [image/png]
# Saving to: ‘퍼셉트론.png’
#
# 퍼셉트론.png        100%[===================>]  17.65K  --.-KB/s    in 0s
#
# 2020-06-10 05:04:01 (109 MB/s) - ‘퍼셉트론.png’ saved [18076/18076]

# %%
#Q3. 위의 그림에 맞는 신경망을 코드로 설계하시오.
n = 4 # ?을 채우시오
n_inputs = 4  # ?을 채우시오
n_hidden = 4 # ?을 채우시오 
n_outputs = 2 # ?을 채우시오  
X=tf.placeholder(tf.float64, shape=(None, n_inputs), name='X') # ?을 채우시오
with tf.name_scope('nn'):
  hidden1 = make_nn_layer('hidden', n_hidden, X, activation=tf.nn.relu) # ?을 채우시오
  outputs = make_nn_layer('outputs', n_outputs, n_hidden) # ?을 채우시오

# %% [markdown]
# Q4. 아래의 표를 보고 Keras 코드를 완성하시오

# %%
#Q4 표
from __future__ import print_function
from matplotlib import pyplot as plt

import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.utils import np_utils
from keras import backend as K

model_m = Sequential()
model_m.add(Conv2D(32, (5, 5), input_shape=(28, 28, 1), activation='relu'))
model_m.add(MaxPooling2D(pool_size=(2, 2)))
model_m.add(Dropout(0.5))
model_m.add(Conv2D(64, (3, 3), activation='relu'))
model_m.add(MaxPooling2D(pool_size=(2, 2)))
model_m.add(Dropout(0.2))
model_m.add(Conv2D(128, (1, 1), activation='relu'))
model_m.add(MaxPooling2D(pool_size=(2, 2)))
model_m.add(Dropout(0.2))
model_m.add(Flatten())
model_m.add(Dense(128, activation='relu'))
model_m.add(Dense(10, activation='softmax'))

print(model_m.summary())

"""
Layer (type)                 Output Shape              Param #   
=================================================================
conv2d_6 (Conv2D)            (None, 24, 24, 32)        832       
_________________________________________________________________
max_pooling2d_5 (MaxPooling2 (None, 12, 12, 32)        0         
_________________________________________________________________
dropout_6 (Dropout)          (None, 12, 12, 32)        0         
_________________________________________________________________
conv2d_7 (Conv2D)            (None, 10, 10, 64)        18496     
_________________________________________________________________
max_pooling2d_6 (MaxPooling2 (None, 5, 5, 64)          0         
_________________________________________________________________
dropout_7 (Dropout)          (None, 5, 5, 64)          0         
_________________________________________________________________
conv2d_8 (Conv2D)            (None, 5, 5, 128)         8320      
_________________________________________________________________
max_pooling2d_7 (MaxPooling2 (None, 2, 2, 128)         0         
_________________________________________________________________
dropout_8 (Dropout)          (None, 2, 2, 128)         0         
_________________________________________________________________
flatten_3 (Flatten)          (None, 512)               0         
_________________________________________________________________
dense_5 (Dense)              (None, 128)               65664     
_________________________________________________________________
dense_6 (Dense)              (None, 10)                1290      
=================================================================

"""
# Out:
# Model: "sequential_16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_7 (Conv2D)            (None, 24, 24, 32)        832
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 12, 12, 32)        0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 12, 12, 32)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 10, 10, 64)        18496
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 5, 5, 64)          0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 5, 5, 128)         8320
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 2, 2, 128)         0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 2, 2, 128)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dense_24 (Dense)             (None, 128)               65664
# _________________________________________________________________
# dense_25 (Dense)             (None, 10)                1290
# =================================================================
# Total params: 94,602
# Trainable params: 94,602
# Non-trainable params: 0
# _________________________________________________________________
# None
# '\nLayer (type)                 Output Shape              Param #   \n=================================================================\nconv2d_6 (Conv2D)            (None, 24, 24, 32)        832       \n_________________________________________________________________\nmax_pooling2d_5 (MaxPooling2 (None, 12, 12, 32)        0         \n_________________________________________________________________\ndropout_6 (Dropout)          (None, 12, 12, 32)        0         \n_________________________________________________________________\nconv2d_7 (Conv2D)            (None, 10, 10, 64)        18496     \n_________________________________________________________________\nmax_pooling2d_6 (MaxPooling2 (None, 5, 5, 64)          0         \n_________________________________________________________________\ndropout_7 (Dropout)          (None, 5, 5, 64)          0         \n_________________________________________________________________\nconv2d_8 (Conv2D)            (None, 5, 5, 128)         8320      \n_________________________________________________________________\nmax_pooling2d_7 (MaxPooling2 (None, 2, 2, 128)         0         \n_________________________________________________________________\ndropout_8 (Dropout)          (None, 2, 2, 128)         0         \n_________________________________________________________________\nflatten_3 (Flatten)          (None, 512)               0         \n_________________________________________________________________\ndense_5 (Dense)              (None, 128)               65664     \n_________________________________________________________________\ndense_6 (Dense)              (None, 10)                1290      \n=================================================================\n\n'

# %%
# Q4. 이곳에 위의 표에 맞는 딥러닝의 모델을 Keras로 코딩하십시오. 모델 부문만 작성하고 마지막에 print로 summary를 출력하십시오.
# 가정 1 : input은 24 x 24의 흑백 이미지
# 가정 2 : convolution layer에서 사용하는 activation function은 ReLU로 통일 
# 가정 3 : maxpooling 시 pool_size는 2 x 2
# 가정 4 : dropout rate는 0.5
# 가정 5 : dense_5 layer에서 사용하는 activation function은 ReLU
# 가정 6 : dense_6 layer에서 사용하는 activation function은 softmax
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras import backend as K

mymodel = Sequential()
mymodel.add(Conv2D(32, (5, 5), input_shape=(28, 28, 1), activation='relu'))
mymodel.add(MaxPooling2D(pool_size=(2, 2)))
mymodel.add(Dropout(0.5))
mymodel.add(Conv2D(64, (3, 3), activation='relu'))
mymodel.add(MaxPooling2D(pool_size=(2, 2)))
mymodel.add(Dropout(0.2))
mymodel.add(Conv2D(128, (1, 1), activation='relu'))
mymodel.add(MaxPooling2D(pool_size=(2, 2)))
mymodel.add(Dropout(0.2))
mymodel.add(Flatten())
mymodel.add(Dense(128, activation='relu'))
mymodel.add(Dense(10, activation='softmax'))

print(mymodel.summary())
# The End
# Out:
# Model: "sequential_18"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_13 (Conv2D)           (None, 24, 24, 32)        832
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 12, 12, 32)        0
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 12, 12, 32)        0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 10, 10, 64)        18496
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 5, 5, 64)          0
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 5, 5, 64)          0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 5, 5, 128)         8320
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 2, 2, 128)         0
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 2, 2, 128)         0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dense_28 (Dense)             (None, 128)               65664
# _________________________________________________________________
# dense_29 (Dense)             (None, 10)                1290
# =================================================================
# Total params: 94,602
# Trainable params: 94,602
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# Q5. 아래  코드가 출력하는 그래프에서 validation loss 값이 모든 epoch 구간에서 training loss 값보다 작도록  코드를 수정하시오. 현재의 그래프는 최적 상태가 아닙니다.

# %%
from keras.datasets import mnist
from matplotlib import pyplot as plt
plt.style.use('dark_background')
from keras.models import Sequential
from keras.layers import Dense, Flatten, Activation, Dropout
from keras.utils import normalize, to_categorical

(X_train, y_train), (X_test, y_test) = mnist.load_data()

plt.imshow(X_train[0], cmap = plt.cm.binary)
plt.show()

X_train = normalize(X_train, axis=1)
X_test = normalize(X_test, axis=1)
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

model = Sequential()
model.add(Flatten(input_shape=(28, 28)))
model.add(Dense(128))
model.add(Activation('relu'))
model.add(Dense(128))
model.add(Activation('relu'))
model.add(Dense(10))
model.add(Activation('softmax'))
model.summary()

model.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)
history = model.fit(
    X_train,
    y_train,
    epochs=10,
    batch_size=32,
    validation_split=0.001,
    verbose = 1,
    shuffle=True
)

loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_9 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dense_25 (Dense)             (None, 128)               100480
# _________________________________________________________________
# activation_25 (Activation)   (None, 128)               0
# _________________________________________________________________
# dense_26 (Dense)             (None, 128)               16512
# _________________________________________________________________
# activation_26 (Activation)   (None, 128)               0
# _________________________________________________________________
# dense_27 (Dense)             (None, 10)                1290
# _________________________________________________________________
# activation_27 (Activation)   (None, 10)                0
# =================================================================
# Total params: 118,282
# Trainable params: 118,282
# Non-trainable params: 0
# _________________________________________________________________
# Train on 59940 samples, validate on 60 samples
# Epoch 1/10
# 59940/59940 [==============================] - 5s 87us/step - loss: 0.2573 - accuracy: 0.9246 - val_loss: 0.0218 - val_accuracy: 1.0000
# Epoch 2/10
# 59940/59940 [==============================] - 5s 79us/step - loss: 0.1057 - accuracy: 0.9675 - val_loss: 0.0257 - val_accuracy: 1.0000
# Epoch 3/10
# 59940/59940 [==============================] - 5s 78us/step - loss: 0.0727 - accuracy: 0.9771 - val_loss: 0.0074 - val_accuracy: 1.0000
# Epoch 4/10
# 59940/59940 [==============================] - 5s 80us/step - loss: 0.0543 - accuracy: 0.9817 - val_loss: 0.0485 - val_accuracy: 0.9833
# Epoch 5/10
# 59940/59940 [==============================] - 5s 78us/step - loss: 0.0412 - accuracy: 0.9867 - val_loss: 0.0786 - val_accuracy: 0.9833
# Epoch 6/10
# 59940/59940 [==============================] - 5s 78us/step - loss: 0.0313 - accuracy: 0.9894 - val_loss: 0.0124 - val_accuracy: 1.0000
# Epoch 7/10
# 59940/59940 [==============================] - 5s 78us/step - loss: 0.0257 - accuracy: 0.9913 - val_loss: 0.0094 - val_accuracy: 1.0000
# Epoch 8/10
# 59940/59940 [==============================] - 5s 81us/step - loss: 0.0202 - accuracy: 0.9934 - val_loss: 0.0043 - val_accuracy: 1.0000
# Epoch 9/10
# 59940/59940 [==============================] - 5s 78us/step - loss: 0.0184 - accuracy: 0.9935 - val_loss: 1.4703e-04 - val_accuracy: 1.0000
# Epoch 10/10
# 59940/59940 [==============================] - 5s 79us/step - loss: 0.0154 - accuracy: 0.9947 - val_loss: 0.0055 - val_accuracy: 1.0000

# %% [markdown]
# Q6. Mini-batch size & Learning Rate 튜닝

# %%
# mlp for the blobs problem with minibatch gradient descent with varied batch size
# 아래의 코드에서 다음 두 개의 파라미터를 조합하여 최고의 모델링 성능을 내고 그 결과를 print()로 출력하십시오.
# 튜닝할 파라미터 : batch_size & lr (각각 3가지의 옵션이 있으므로 두 파라미터를 조합할 수 있는 경우의 수는 모두 9가지)
# 모델의 성능 평가 기준은 다음의 우선순위에 따라 결정하시오. 
# 1. Validation Loss가 최소, 2. Accuracy는 최고값에 가까울 것
# 9번의 실험 후 최적이라고 생각되는 파라미터 값을 코드에 지정하고 셀을 다시 run하여 최종 결과를 출력하시오.
# %%time
from sklearn.datasets import make_blobs
from keras.layers import Dense
from keras.models import Sequential
from keras.optimizers import SGD
from keras.utils import to_categorical
from matplotlib import pyplot

# prepare train and test dataset
def prepare_data():
	# generate 2d classification dataset
	X, y = make_blobs(n_samples=1000, centers=3, n_features=2, cluster_std=2, random_state=2)
	# one hot encode output variable
	y = to_categorical(y)
	# split into train and test
	n_train = 500
	trainX, testX = X[:n_train, :], X[n_train:, :]
	trainy, testy = y[:n_train], y[n_train:]
	return trainX, trainy, testX, testy

# fit a model and plot learning curve
def fit_model(trainX, trainy, testX, testy, n_batch):
	
  # define model
	model = Sequential()
	model.add(Dense(50, input_dim=2, activation='relu', kernel_initializer='he_uniform'))
	model.add(Dense(3, activation='softmax'))
	
  # lr의 값을  0.1, 0.01, 0.001 중에서 선택하여 이곳에 지정
	opt = SGD(lr=0.001, momentum=0.9) 
	model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
	# fit model
	history = model.fit(trainX, trainy, validation_data=(testX, testy), epochs=150, verbose=2, batch_size=n_batch)
	print('accuracy = ', format(history.history['accuracy'][149],".3f"), ' ', 'validation loss = ', format(history.history['val_loss'][149],".3f"))
  # plot learning curves
	pyplot.plot(history.history['accuracy'], label='train')
	pyplot.plot(history.history['val_loss'], label='test')
	pyplot.title('batch='+str(n_batch), pad=-40)



# prepare dataset
trainX, trainy, testX, testy = prepare_data()

# batch_size의 값을   16, 32, 64 중에서 선택하여 이곳에 지정
batch_size = 16

fit_model(trainX, trainy, testX, testy, batch_size)
# show learning curves
pyplot.show()

# 결과를 메모장에 적어놓고 lr과 batch_size를 바꿔가며 최적의 파라미터를 찾아가시오.
# 최적의 lr과 batch_size를 선택하여 위의 코드에 적고 Run한 결과룰 출력하여 제출하시오. 

# 0.1 16 0.928 0.670
#0.1 32 0.571 0.804
#0.1 64 0.502 0.842

#0.01 16 0.443 0.820
#0.01 32 0.438 0.832
#0.01 64 0.432 0.816

#0.001 16 0.400 0.830 = Validation Loss가 1번째로 최소값이고, Accuracy값이 3번째로 최고점이여서 이 값들을 선택했습니다.
#0.001 32 0.426 0.794
#0.001 64 0.520 0.784
# Out:
# Train on 500 samples, validate on 500 samples
# Epoch 1/150
#  - 0s - loss: 1.6210 - accuracy: 0.4540 - val_loss: 0.9525 - val_accuracy: 0.5220
# Epoch 2/150
#  - 0s - loss: 0.9125 - accuracy: 0.5740 - val_loss: 0.6920 - val_accuracy: 0.7120
# Epoch 3/150
#  - 0s - loss: 0.7745 - accuracy: 0.6100 - val_loss: 0.6484 - val_accuracy: 0.7180
# Epoch 4/150
#  - 0s - loss: 0.7200 - accuracy: 0.6380 - val_loss: 0.6587 - val_accuracy: 0.7260
# Epoch 5/150
#  - 0s - loss: 0.7233 - accuracy: 0.6360 - val_loss: 0.6252 - val_accuracy: 0.7480
# Epoch 6/150
#  - 0s - loss: 0.6895 - accuracy: 0.6580 - val_loss: 0.7114 - val_accuracy: 0.7220
# Epoch 7/150
#  - 0s - loss: 0.6763 - accuracy: 0.6760 - val_loss: 0.6759 - val_accuracy: 0.6720
# Epoch 8/150
#  - 0s - loss: 0.7596 - accuracy: 0.6420 - val_loss: 0.5989 - val_accuracy: 0.7580
# Epoch 9/150
#  - 0s - loss: 0.6531 - accuracy: 0.6700 - val_loss: 0.5842 - val_accuracy: 0.7320
# Epoch 10/150
#  - 0s - loss: 0.6544 - accuracy: 0.6680 - val_loss: 0.5764 - val_accuracy: 0.7440
# Epoch 11/150
#  - 0s - loss: 0.6354 - accuracy: 0.6900 - val_loss: 0.5993 - val_accuracy: 0.7880
# Epoch 12/150
#  - 0s - loss: 0.6400 - accuracy: 0.7140 - val_loss: 0.5946 - val_accuracy: 0.7460
# Epoch 13/150
#  - 0s - loss: 0.6471 - accuracy: 0.7060 - val_loss: 0.6251 - val_accuracy: 0.7080
# Epoch 14/150
#  - 0s - loss: 0.6586 - accuracy: 0.6900 - val_loss: 0.5567 - val_accuracy: 0.7660
# Epoch 15/150
#  - 0s - loss: 0.6295 - accuracy: 0.6760 - val_loss: 0.5928 - val_accuracy: 0.7940
# Epoch 16/150
#  - 0s - loss: 0.6242 - accuracy: 0.7020 - val_loss: 0.5633 - val_accuracy: 0.7420
# Epoch 17/150
#  - 0s - loss: 0.6518 - accuracy: 0.7060 - val_loss: 0.5395 - val_accuracy: 0.7720
# Epoch 18/150
#  - 0s - loss: 0.6150 - accuracy: 0.7060 - val_loss: 0.5509 - val_accuracy: 0.8020
# Epoch 19/150
#  - 0s - loss: 0.5936 - accuracy: 0.7300 - val_loss: 0.6273 - val_accuracy: 0.7820
# Epoch 20/150
#  - 0s - loss: 0.6067 - accuracy: 0.7160 - val_loss: 0.5759 - val_accuracy: 0.7340
# Epoch 21/150
#  - 0s - loss: 0.6091 - accuracy: 0.7240 - val_loss: 0.5216 - val_accuracy: 0.7820
# Epoch 22/150
#  - 0s - loss: 0.5615 - accuracy: 0.7620 - val_loss: 0.6168 - val_accuracy: 0.7720
# Epoch 23/150
#  - 0s - loss: 0.6007 - accuracy: 0.7400 - val_loss: 0.5542 - val_accuracy: 0.7400
# Epoch 24/150
#  - 0s - loss: 0.5958 - accuracy: 0.7200 - val_loss: 0.5426 - val_accuracy: 0.7500
# Epoch 25/150
#  - 0s - loss: 0.5560 - accuracy: 0.7620 - val_loss: 0.5091 - val_accuracy: 0.8140
# Epoch 26/150
#  - 0s - loss: 0.5904 - accuracy: 0.7380 - val_loss: 0.5573 - val_accuracy: 0.8080
# Epoch 27/150
#  - 0s - loss: 0.5592 - accuracy: 0.7500 - val_loss: 0.5009 - val_accuracy: 0.8120
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import numpy as np
from tensorflow.keras.utils import to_categorical

text="""특히 최근 수도권에서는 교회 소모임 참석자에 이어 이들 가족과 지인으로 번지는 2차 감염 사례가 증가하고 있습니다. 중앙재난안전대책본부는 오늘까지 수도권 교회와 관련한 코로나19 확진자는 총 63명이라고 밝혔으며  2차 감염자는 33명 이라고 전했습니다. """


t = Tokenizer()
t.fit_on_texts([text])
vocab_size = len(t.word_index) + 1
print('단어 집합의 크기 : %d' % vocab_size)


print(t.word_index)

sequences = list()
for line in text.split('\n'): 
    encoded = t.texts_to_sequences([line])[0]
    for i in range(1, len(encoded)):
        sequence = encoded[:i+1]
        sequences.append(sequence)

print('학습에 사용할 샘플의 개수: %d' % len(sequences))


max_len=max(len(l) for l in sequences) 

sequences = pad_sequences(sequences, maxlen=max_len, padding='pre')

sequences = np.array(sequences)
X = sequences[:,:-1]
y = sequences[:,-1]


from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Dense, SimpleRNN

model = Sequential()
model.add(Embedding(vocab_size, 10, input_length=max_len-1))  
model.add(SimpleRNN(32))
model.add(Dense(vocab_size, activation='softmax'))
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X, y, epochs=120, verbose=2)

# 이 블록에서 yoou_code_here 부분을 완성하시오
def sentence_generation(model, t, current_word, n): # model = 모델, t = 토크나이저, current_word = 현재 단어, n = 반복할 횟수
    init_word = current_word # 처음 들어온 단어도 마지막에 같이 출력하기위해 저장
    sentence = ''
    for _ in range(n): # n번 반복
        encoded = t.texts_to_sequences([current_word])[0] # 현재 단어에 대한 정수 인코딩
        encoded = pad_sequences([encoded], maxlen=30, padding='pre') # 데이터에 대한 패딩
        result = np.argmax(model.predict(encoded), axis=-1)
        for word, index in t.word_index.items(): 
            if index == result: # 만약 예측한 단어의 인덱스 값이 동일한 단어가 있다면
                break # 해당 단어가 예측 단어이므로 break
        current_word =  current_word + ' '  + word # 현재 단어 + ' ' + 예측한 단어를 current_word로 저장
        sentence = sentence + ' ' + word  # 예측한 단어를 sentence에 append
     
    sentence = init_word + sentence # 초기의 텍스트와 for loop에서 생성된 텍스트를 concatenate
    return sentence

print(sentence_generation(model, t, '특히', 10))
# Out:
# 단어 집합의 크기 : 31
# {'2차': 1, '특히': 2, '최근': 3, '수도권에서는': 4, '교회': 5, '소모임': 6, '참석자에': 7, '이어': 8, '이들': 9, '가족과': 10, '지인으로': 11, '번지는': 12, '감염': 13, '사례가': 14, '증가하고': 15, '있습니다': 16, '중앙재난안전대책본부는': 17, '오늘까지': 18, '수도권': 19, '교회와': 20, '관련한': 21, '코로나19': 22, '확진자는': 23, '총': 24, '63명이라고': 25, '밝혔으며': 26, '감염자는': 27, '33명': 28, '이라고': 29, '전했습니다': 30}
# 학습에 사용할 샘플의 개수: 30
# Epoch 1/120
# 1/1 - 0s - loss: 3.4678 - accuracy: 0.0333
# Epoch 2/120
# 1/1 - 0s - loss: 3.4488 - accuracy: 0.0667
# Epoch 3/120
# 1/1 - 0s - loss: 3.4323 - accuracy: 0.0667
# Epoch 4/120
# 1/1 - 0s - loss: 3.4177 - accuracy: 0.0333
# Epoch 5/120
# 1/1 - 0s - loss: 3.4042 - accuracy: 0.0667
# Epoch 6/120
# 1/1 - 0s - loss: 3.3912 - accuracy: 0.1667
# Epoch 7/120
# 1/1 - 0s - loss: 3.3782 - accuracy: 0.1667
# Epoch 8/120
# 1/1 - 0s - loss: 3.3649 - accuracy: 0.1333
# Epoch 9/120
# 1/1 - 0s - loss: 3.3511 - accuracy: 0.1333
# Epoch 10/120
# Epoch 48/120
# 1/1 - 0s - loss: 2.4350 - accuracy: 0.6000
# Epoch 49/120
# 1/1 - 0s - loss: 2.4067 - accuracy: 0.5667
# Epoch 50/120
# 1/1 - 0s - loss: 2.3786 - accuracy: 0.5667
# Epoch 51/120
# 1/1 - 0s - loss: 2.3506 - accuracy: 0.5667
# Epoch 52/120
# 1/1 - 0s - loss: 2.3226 - accuracy: 0.5667
# Epoch 53/120
# 1/1 - 0s - loss: 2.2941 - accuracy: 0.6000
# Epoch 54/120
# 1/1 - 0s - loss: 2.2652 - accuracy: 0.6333
# Epoch 55/120
# 1/1 - 0s - loss: 2.2360 - accuracy: 0.6333
# Epoch 56/120
# 1/1 - 0s - loss: 2.2071 - accuracy: 0.7000
# Epoch 57/120
# 1/1 - 0s - loss: 2.1784 - accuracy: 0.7000
# Epoch 58/120
# 1/1 - 0s - loss: 2.1495 - accuracy: 0.8000
# Epoch 59/120
# 1/1 - 0s - loss: 2.1203 - accuracy: 0.8333
# Epoch 60/120
# 1/1 - 0s - loss: 2.0916 - accuracy: 0.8667
# Epoch 61/120
# 1/1 - 0s - loss: 2.0626 - accuracy: 0.8667
# Epoch 62/120
# 1/1 - 0s - loss: 2.0334 - accuracy: 0.8667
# Epoch 63/120
# 1/1 - 0s - loss: 2.0046 - accuracy: 0.9000
# Epoch 64/120
# 1/1 - 0s - loss: 1.9758 - accuracy: 0.9000
# Epoch 65/120
# 1/1 - 0s - loss: 1.9469 - accuracy: 0.9000
# Epoch 66/120
# 1/1 - 0s - loss: 1.9179 - accuracy: 0.9000
# Epoch 67/120
# 1/1 - 0s - loss: 1.8891 - accuracy: 0.9000
# Epoch 68/120
# 1/1 - 0s - loss: 1.8603 - accuracy: 0.9000
# Epoch 69/120
# 1/1 - 0s - loss: 1.8318 - accuracy: 0.9000
# Epoch 70/120
# 1/1 - 0s - loss: 1.8032 - accuracy: 0.9000
# Epoch 71/120
# 1/1 - 0s - loss: 1.7748 - accuracy: 0.9000
# Epoch 72/120
# 1/1 - 0s - loss: 1.7466 - accuracy: 0.9000
# Epoch 73/120
# 1/1 - 0s - loss: 1.7187 - accuracy: 0.9000
# Epoch 74/120
# 1/1 - 0s - loss: 1.6913 - accuracy: 0.9000
# Epoch 75/120
# 1/1 - 0s - loss: 1.6674 - accuracy: 0.9000
# Epoch 76/120
# 1/1 - 0s - loss: 1.6440 - accuracy: 0.9000
# Epoch 77/120
# 1/1 - 0s - loss: 1.6132 - accuracy: 0.9000
# Epoch 78/120
# 1/1 - 0s - loss: 1.5885 - accuracy: 0.9000
# Epoch 79/120
# 1/1 - 0s - loss: 1.5636 - accuracy: 0.9000
# Epoch 80/120
# 1/1 - 0s - loss: 1.5382 - accuracy: 0.9000
# Epoch 81/120
# 1/1 - 0s - loss: 1.5142 - accuracy: 0.9000
# Epoch 82/120
# 1/1 - 0s - loss: 1.4902 - accuracy: 0.9000
# Epoch 83/120
# 1/1 - 0s - loss: 1.4669 - accuracy: 0.9000
# Epoch 84/120
# 1/1 - 0s - loss: 1.4427 - accuracy: 0.9000
# Epoch 85/120
# 1/1 - 0s - loss: 1.4220 - accuracy: 0.9000
# Epoch 86/120
# 1/1 - 0s - loss: 1.3978 - accuracy: 0.9000
# Epoch 87/120
# 1/1 - 0s - loss: 1.3760 - accuracy: 0.9000
# Epoch 88/120
# 1/1 - 0s - loss: 1.3546 - accuracy: 0.9000
# Epoch 89/120
# 1/1 - 0s - loss: 1.3317 - accuracy: 0.9000
# Epoch 90/120
# 1/1 - 0s - loss: 1.3118 - accuracy: 0.9000
# Epoch 91/120
# 1/1 - 0s - loss: 1.2913 - accuracy: 0.9000
# Epoch 92/120
# 1/1 - 0s - loss: 1.2742 - accuracy: 0.9000
# Epoch 93/120
# 1/1 - 0s - loss: 1.2617 - accuracy: 0.9000
# Epoch 94/120
# 1/1 - 0s - loss: 1.2351 - accuracy: 0.9000
# Epoch 95/120
# 1/1 - 0s - loss: 1.2128 - accuracy: 0.9000
# Epoch 96/120
# 1/1 - 0s - loss: 1.1970 - accuracy: 0.9333
# Epoch 97/120
# 1/1 - 0s - loss: 1.1770 - accuracy: 0.9333
# Epoch 98/120
# 1/1 - 0s - loss: 1.1570 - accuracy: 0.9333
# Epoch 99/120
# 1/1 - 0s - loss: 1.1414 - accuracy: 0.9333
# Epoch 100/120
# 1/1 - 0s - loss: 1.1215 - accuracy: 0.9333
# Epoch 101/120
# 1/1 - 0s - loss: 1.1057 - accuracy: 0.9333
# Epoch 102/120
# 1/1 - 0s - loss: 1.0887 - accuracy: 0.9333
# Epoch 103/120
# 1/1 - 0s - loss: 1.0701 - accuracy: 0.9333
# Epoch 104/120
# 1/1 - 0s - loss: 1.0555 - accuracy: 0.9333
# Epoch 105/120
# 1/1 - 0s - loss: 1.0376 - accuracy: 0.9333
# Epoch 106/120
# 1/1 - 0s - loss: 1.0214 - accuracy: 0.9333
# Epoch 107/120
# 1/1 - 0s - loss: 1.0067 - accuracy: 0.9333
# Epoch 108/120
# 1/1 - 0s - loss: 0.9908 - accuracy: 0.9333
# Epoch 109/120
# 1/1 - 0s - loss: 0.9746 - accuracy: 0.9333
# Epoch 110/120
# 1/1 - 0s - loss: 0.9605 - accuracy: 0.9333
# Epoch 111/120
# 1/1 - 0s - loss: 0.9453 - accuracy: 0.9333
# Epoch 112/120
# 1/1 - 0s - loss: 0.9305 - accuracy: 0.9333
# Epoch 113/120
# 1/1 - 0s - loss: 0.9160 - accuracy: 0.9333
# Epoch 114/120
# 1/1 - 0s - loss: 0.9022 - accuracy: 0.9333
# Epoch 115/120
# 1/1 - 0s - loss: 0.8882 - accuracy: 0.9333
# Epoch 116/120
# 1/1 - 0s - loss: 0.8734 - accuracy: 0.9333
# Epoch 117/120
# 1/1 - 0s - loss: 0.8615 - accuracy: 0.9333
# Epoch 118/120
# 1/1 - 0s - loss: 0.8473 - accuracy: 0.9333
# Epoch 119/120
# 1/1 - 0s - loss: 0.8339 - accuracy: 0.9333
# Epoch 120/120
# 1/1 - 0s - loss: 0.8214 - accuracy: 0.9333
# 특히 최근 수도권에서는 최근 수도권에서는 참석자에 이어 이들 가족과 지인으로 번지는

# %% [markdown]
# ## 20년1학기-기말고사-yourname.ipynb로 다운로드한 후 제출하십시오.
# 수고하였습니다!
